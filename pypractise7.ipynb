# %% [markdown]
# ### SEABORN

# %% [markdown]
# ### Distribution plots
# - distplot
# - joinlot
# - pairplot
#
# practise problem in iris dataset

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# one feature f1 is called univariate analysis
# 2 features f1 and f2 bivariate analysis - 2d 
# if u have more than 3 features what we will do ??? 3d, and 4d - so we use pairplot

# %% [markdown]
# here , tips column will be dependent feature and rest all the other columnn are independent features
# ((very important))

# %% [markdown]
# #### Correlation with Heatmap
#
# A correlation heatmap uses colored cells, typically in a monochromatic scale, to show a 2D correlation matrix (table) between two discrete dimensions or event types. It is very important in Feature selection.

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# positively correlated means when x inc than y inc , vice versa

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ### JoinPlot

# %% [markdown]
# A join plot allows to study the relationship between 2 numeric variables . The central chart display their correlation.
# It is usually a scatterplot , a hexbin plot, a 2D histogram or a 2D density plot.

# %% [markdown]
# #### Univariate Analysis

# %%
sns.jointplot(x= 'tip', y = 'total_bill', data = df, kind='hex')

# %%
sns.jointplot(x= 'tip', y = 'total_bill', data=df, kind='reg')

# %% [markdown]
# ### Pair plot

# %% [markdown]
# A “pairs plot” is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value, like this: Pairs plots are just elaborations on this, showing all variables paired with all the other variables

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='sex')

# %% [markdown]
# ### Dist Plot
# Dist plot helps us to check the distribution of the columns feature

# %%
sns.distplot(df['tip'])

# %%
sns.distplot(df['tip'], kde=False, bins=10)
